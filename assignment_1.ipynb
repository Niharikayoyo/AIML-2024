# %%
import pandas as pd
file=pd.read_excel("/nishuuu.xlsx")
file
# Out:
#    sn    NAME  Gender nationality  Unnamed: 4 organization  Unnamed: 6  \
# 0   1   Nishu  female       china         NaN       google         NaN
# 1   2  varsha  female       asian         NaN    microsoft         NaN
# 2   3  nandhu  female       india         NaN       amazon         NaN
# 3   4   puppy  female       india         NaN        wipro         NaN
#
#    work experience(in year)
# 0                         5
# 1                         8
# 2                        10
# 3                         7

# %%
import pandas as pd
file=pd.read_table("/nishuuu.txt")
file
# Out:
#    sn    NAME  Gender nationality  Unnamed: 4 organization  Unnamed: 6  \
# 0   1   Nishu  female       china         NaN       google         NaN
# 1   2  varsha  female       asian         NaN    microsoft         NaN
# 2   3  nandhu  female       india         NaN       amazon         NaN
# 3   4   puppy  female       india         NaN        wipro         NaN
#
#    work experience(in year)
# 0                         5
# 1                         8
# 2                        10
# 3                         7

# %%
import pandas as pd
file=pd.read_csv("/nishuuu.csv")
file
# Out:
#    sn    NAME  Gender nationality  Unnamed: 4 organization  Unnamed: 6  \
# 0   1   Nishu  female       china         NaN       google         NaN
# 1   2  varsha  female       asian         NaN    microsoft         NaN
# 2   3  nandhu  female       india         NaN       amazon         NaN
# 3   4   puppy  female       india         NaN        wipro         NaN
#
#    work experience(in year)
# 0                         5
# 1                         8
# 2                        10
# 3                         7
